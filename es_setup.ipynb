# %% [markdown]
# # Elastic search config

# %% [markdown]
# ### Test connection

# %%
import requests
from requests.auth import HTTPBasicAuth

# Elasticsearch connection settings
es_url = "http://localhost:9201"
es_user = "elastic"
es_password = "apppw"

try:
    response = requests.get(f"{es_url}/", auth=HTTPBasicAuth(es_user, es_password), timeout=5)
    if response.status_code == 200:
        print("Successfully connected to Elasticsearch!")
    else:
        print(f"Failed to connect to Elasticsearch: {response.status_code} {response.text}")
except Exception as e:
    print(f"Error connecting to Elasticsearch: {e}")
# Out:
# Successfully connected to Elasticsearch!
# /Users/wexorsj/Github/elasticsearch-vs-mysql-playground/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Create empty Index

# %%
from elasticsearch import Elasticsearch

# Connection
es_url = "http://localhost:9201"
es_user = "elastic"
es_password = "apppw"
index_name = "my_index"

es = Elasticsearch(
    es_url,
    basic_auth=(es_user, es_password)
)

# 1. Delete index if it already exists
if es.indices.exists(index=index_name):
    es.indices.delete(index=index_name)
    print(f"Deleted old index: {index_name}")

# 2. Define settings + mappings
settings = {
    "settings": {
        "analysis": {
            "analyzer": {
                "ngram_analyzer": {
                    "tokenizer": "ngram_tokenizer"
                }
            },
            "tokenizer": {
                "ngram_tokenizer": {
                    "type": "ngram",
                    "min_gram": 3,
                    "max_gram": 4,
                    "token_chars": ["letter", "digit"]
                }
            }
        }
    },
    "mappings": {
        "properties": {
            "title": {
                "type": "text",
                "fields": {
                    "standard": {"type": "text", "analyzer": "standard"},
                    "ngram": {"type": "text", "analyzer": "ngram_analyzer"}
                }
            },
            "year": {"type": "integer"},
            "genre": {"type": "keyword"}
        }
    }
}


# 3. Create index
es.indices.create(index=index_name, body=settings)
print(f"Created index: {index_name}")
# Out:
# Deleted old index: imdb_unindexed
# Created index: imdb_unindexed

# %% [markdown]
# ### Fill index

# %%
from elasticsearch import Elasticsearch, helpers
import pandas as pd
import numpy as np
import time

# Elasticsearch connection
es_url = "http://localhost:9201"
es_user = "elastic"
es_password = "apppw"
index_name = "my_index"

es = Elasticsearch(es_url, basic_auth=(es_user, es_password))

# Load CSV
csv_file = "products-2000000.csv"  # or larger CSV
df = pd.read_csv(csv_file)

# Replace NaN with None
df = df.where(pd.notnull(df), None)

# Rename columns if necessary (match ES mapping)
# For example: 'Title', 'Year', 'Genre'
# Make sure the column names match the mappings
# df.rename(columns={"OldName": "NewName"}, inplace=True)

# Convert DataFrame to dicts for ES
records = df.to_dict(orient="records")

batch_size = 1000  # tweak based on memory / ES capacity
start_time = time.time()

print("Starting to insert rows")

for start in range(0, len(records), batch_size):
    end = start + batch_size
    batch = records[start:end]
    actions = [
        {
            "_index": index_name,
            "_source": rec
        }
        for rec in batch
    ]
    helpers.bulk(es, actions)

elapsed = time.time() - start_time
print(f"Finished inserting {len(records)} rows into '{index_name}' in {elapsed:.2f} seconds")
# Out:
# Inserted rows 0–1000
# Inserted rows 1000–2000
# Inserted rows 2000–3000
# Inserted rows 3000–4000
# Inserted rows 4000–5000
# Inserted rows 5000–6000
# Inserted rows 6000–7000
# Inserted rows 7000–8000
# Inserted rows 8000–9000
# Inserted rows 9000–10000
# Inserted rows 10000–11000
# Inserted rows 11000–12000
# Inserted rows 12000–13000
# Inserted rows 13000–14000
# Inserted rows 14000–15000
# Inserted rows 15000–16000
# Inserted rows 16000–17000
# Inserted rows 17000–18000
# Inserted rows 18000–19000
# Inserted rows 19000–20000
# Inserted rows 20000–21000
# Inserted rows 21000–22000
# Inserted rows 22000–23000
# Inserted rows 23000–24000
# Inserted rows 24000–25000
# Inserted rows 25000–26000
# Inserted rows 26000–27000
# Inserted rows 27000–28000
# Inserted rows 28000–29000
# Inserted rows 29000–30000
# Inserted rows 30000–31000
# Inserted rows 31000–32000
# Inserted rows 32000–33000
# Inserted rows 33000–34000
# Inserted rows 34000–35000
# Inserted rows 35000–36000
# Inserted rows 36000–37000
# Inserted rows 37000–38000
# Inserted rows 38000–39000
# Inserted rows 39000–40000
# Inserted rows 40000–41000
# Inserted rows 41000–42000
# Inserted rows 42000–43000
# Inserted rows 43000–44000
# Inserted rows 44000–45000
# Inserted rows 45000–46000
# Inserted rows 46000–47000
# Inserted rows 47000–48000
# Inserted rows 48000–49000
# Inserted rows 49000–50000
# Inserted rows 50000–51000
# Inserted rows 51000–52000
# Inserted rows 52000–53000
# Inserted rows 53000–54000
# Inserted rows 54000–55000
# Inserted rows 55000–56000
# Inserted rows 56000–57000
# Inserted rows 57000–58000
# Inserted rows 58000–59000
# Inserted rows 59000–60000
# Inserted rows 60000–61000
# Inserted rows 61000–62000
# Inserted rows 62000–63000
# Inserted rows 63000–64000
# Inserted rows 64000–65000
# Inserted rows 65000–66000
# Inserted rows 66000–67000
# Inserted rows 67000–68000
# Inserted rows 68000–69000
# Inserted rows 69000–70000
# Inserted rows 70000–71000
# Inserted rows 71000–72000
# Inserted rows 72000–73000
# Inserted rows 73000–74000
# Inserted rows 74000–75000
# Inserted rows 75000–76000
# Inserted rows 76000–77000
# Inserted rows 77000–78000
# Inserted rows 78000–79000
# Inserted rows 79000–80000
# Inserted rows 80000–81000
# Inserted rows 81000–82000
# Inserted rows 82000–83000
# Inserted rows 83000–84000
# Inserted rows 84000–85000
# Inserted rows 85000–86000
# Inserted rows 86000–87000
# Inserted rows 87000–88000
# Inserted rows 88000–89000
# Inserted rows 89000–90000
# Inserted rows 90000–91000
# Inserted rows 91000–92000
# Inserted rows 92000–93000
# Inserted rows 93000–94000
# Inserted rows 94000–95000
# Inserted rows 95000–96000
# Inserted rows 96000–97000
# Inserted rows 97000–98000
# Inserted rows 98000–99000
# Inserted rows 99000–100000
# Inserted rows 100000–101000
# Inserted rows 101000–102000
# Inserted rows 102000–103000
# Inserted rows 103000–104000
# Inserted rows 104000–105000
# Inserted rows 105000–106000
# Inserted rows 106000–107000
# Inserted rows 107000–108000
# Inserted rows 108000–109000
# Inserted rows 109000–110000
# Inserted rows 110000–111000
# Inserted rows 111000–112000
# Inserted rows 112000–113000
# Inserted rows 113000–114000
# Inserted rows 114000–115000
# Inserted rows 115000–116000
# Inserted rows 116000–117000
# Inserted rows 117000–118000
# Inserted rows 118000–119000
# Inserted rows 119000–120000
# Inserted rows 120000–121000
# Inserted rows 121000–122000
# Inserted rows 122000–123000
# Inserted rows 123000–124000
# Inserted rows 124000–125000
# Inserted rows 125000–126000
# Inserted rows 126000–127000
# Inserted rows 127000–128000
# Inserted rows 128000–129000
# Inserted rows 129000–130000
# Inserted rows 130000–131000
# Inserted rows 131000–132000
# Inserted rows 132000–133000
# Inserted rows 133000–134000
# Inserted rows 134000–135000
# Inserted rows 135000–136000
# Inserted rows 136000–137000
# Inserted rows 137000–138000
# Inserted rows 138000–139000
# Inserted rows 139000–140000
# Inserted rows 140000–141000
# Inserted rows 141000–142000
# Inserted rows 142000–143000
# Inserted rows 143000–144000
# Inserted rows 144000–145000
# Inserted rows 145000–146000
# Inserted rows 146000–147000
# Inserted rows 147000–148000
# Inserted rows 148000–149000
# Inserted rows 149000–150000
# Inserted rows 150000–151000
# Inserted rows 151000–152000
# Inserted rows 152000–153000
# Inserted rows 153000–154000
# Inserted rows 154000–155000
# Inserted rows 155000–156000
# Inserted rows 156000–157000
# Inserted rows 157000–158000
# Inserted rows 158000–159000
# Inserted rows 159000–160000
# Inserted rows 160000–161000
# Inserted rows 161000–162000
# Inserted rows 162000–163000
# Inserted rows 163000–164000
# Inserted rows 164000–165000
# Inserted rows 165000–166000
# Inserted rows 166000–167000
# Inserted rows 167000–168000
# Inserted rows 168000–169000
# Inserted rows 169000–170000
# Inserted rows 170000–171000
# Inserted rows 171000–172000
# Inserted rows 172000–173000
# Inserted rows 173000–174000
# Inserted rows 174000–175000
# Inserted rows 175000–176000
# Inserted rows 176000–177000
# Inserted rows 177000–178000
# Inserted rows 178000–179000
# Inserted rows 179000–180000
# Inserted rows 180000–181000
# Inserted rows 181000–182000
# Inserted rows 182000–183000
# Inserted rows 183000–184000
# Inserted rows 184000–185000
# Inserted rows 185000–186000
# Inserted rows 186000–187000
# Inserted rows 187000–188000
# Inserted rows 188000–189000
# Inserted rows 189000–190000
# Inserted rows 190000–191000
# Inserted rows 191000–192000
# Inserted rows 192000–193000
# Inserted rows 193000–194000
# Inserted rows 194000–195000
# Inserted rows 195000–196000
# Inserted rows 196000–197000
# Inserted rows 197000–198000
# Inserted rows 198000–199000
# Inserted rows 199000–200000
# Inserted rows 200000–201000
# Inserted rows 201000–202000
# Inserted rows 202000–203000
# Inserted rows 203000–204000
# Inserted rows 204000–205000
# Inserted rows 205000–206000
# Inserted rows 206000–207000
# Inserted rows 207000–208000
# Inserted rows 208000–209000
# Inserted rows 209000–210000
# Inserted rows 210000–211000
# Inserted rows 211000–212000
# Inserted rows 212000–213000
# Inserted rows 213000–214000
# Inserted rows 214000–215000
# Inserted rows 215000–216000
# Inserted rows 216000–217000
# Inserted rows 217000–218000
# Inserted rows 218000–219000
# Inserted rows 219000–220000
# Inserted rows 220000–221000
# Inserted rows 221000–222000
# Inserted rows 222000–223000
# Inserted rows 223000–224000
# Inserted rows 224000–225000
# Inserted rows 225000–226000
# Inserted rows 226000–227000
# Inserted rows 227000–228000
# Inserted rows 228000–229000
# Inserted rows 229000–230000
# Inserted rows 230000–231000
# Inserted rows 231000–232000
# Inserted rows 232000–233000
# Inserted rows 233000–234000
# Inserted rows 234000–235000
# Inserted rows 235000–236000
# Inserted rows 236000–237000
# Inserted rows 237000–238000
# Inserted rows 238000–239000
# Inserted rows 239000–240000
# Inserted rows 240000–241000
# Inserted rows 241000–242000
# Inserted rows 242000–243000
# Inserted rows 243000–244000
# Inserted rows 244000–245000
# Inserted rows 245000–246000
# Inserted rows 246000–247000
# Inserted rows 247000–248000
# Inserted rows 248000–249000
# Inserted rows 249000–250000
# Inserted rows 250000–251000
# Inserted rows 251000–252000
# Inserted rows 252000–253000
# Inserted rows 253000–254000
# Inserted rows 254000–255000
# Inserted rows 255000–256000
# Inserted rows 256000–257000
# Inserted rows 257000–258000
# Inserted rows 258000–259000
# Inserted rows 259000–260000
# Inserted rows 260000–261000
# Inserted rows 261000–262000
# Inserted rows 262000–263000
# Inserted rows 263000–264000
# Inserted rows 264000–265000
# Inserted rows 265000–266000
# Inserted rows 266000–267000
# Inserted rows 267000–268000
# Inserted rows 268000–269000
# Inserted rows 269000–270000
# Inserted rows 270000–271000
# Inserted rows 271000–272000
# Inserted rows 272000–273000
# Inserted rows 273000–274000
# Inserted rows 274000–275000
# Inserted rows 275000–276000
# Inserted rows 276000–277000
# Inserted rows 277000–278000
# Inserted rows 278000–279000
# Inserted rows 279000–280000
# Inserted rows 280000–281000
# Inserted rows 281000–282000
# Inserted rows 282000–283000
# Inserted rows 283000–284000
# Inserted rows 284000–285000
# Inserted rows 285000–286000
# Inserted rows 286000–287000
# Inserted rows 287000–288000
# Inserted rows 288000–289000
# Inserted rows 289000–290000
# Inserted rows 290000–291000
# Inserted rows 291000–292000
# Inserted rows 292000–293000
# Inserted rows 293000–294000
# Inserted rows 294000–295000
# Inserted rows 295000–296000
# Inserted rows 296000–297000
# Inserted rows 297000–298000
# Inserted rows 298000–299000
# Inserted rows 299000–300000
# Inserted rows 300000–301000
# Inserted rows 301000–302000
# Inserted rows 302000–303000
# Inserted rows 303000–304000
# Inserted rows 304000–305000
# Inserted rows 305000–306000
# Inserted rows 306000–307000
# Inserted rows 307000–308000
# Inserted rows 308000–309000
# Inserted rows 309000–310000
# Inserted rows 310000–311000
# Inserted rows 311000–312000
# Inserted rows 312000–313000
# Inserted rows 313000–314000
# Inserted rows 314000–315000
# Inserted rows 315000–316000
# Inserted rows 316000–317000
# Inserted rows 317000–318000
# Inserted rows 318000–319000
# Inserted rows 319000–320000
# Inserted rows 320000–321000
# Inserted rows 321000–322000
# Inserted rows 322000–323000
# Inserted rows 323000–324000
# Inserted rows 324000–325000
# Inserted rows 325000–326000
# Inserted rows 326000–327000
# Inserted rows 327000–328000
# Inserted rows 328000–329000
# Inserted rows 329000–330000
# Inserted rows 330000–331000
# Inserted rows 331000–332000
# Inserted rows 332000–333000
# Inserted rows 333000–334000
# Inserted rows 334000–335000
# Inserted rows 335000–336000
# Inserted rows 336000–337000
# Inserted rows 337000–338000
# Inserted rows 338000–339000
# Inserted rows 339000–340000
# Inserted rows 340000–341000
# Inserted rows 341000–342000
# Inserted rows 342000–343000
# Inserted rows 343000–344000
# Inserted rows 344000–345000
# Inserted rows 345000–346000
# Inserted rows 346000–347000
# Inserted rows 347000–348000
# Inserted rows 348000–349000
# Inserted rows 349000–350000
# Inserted rows 350000–351000
# Inserted rows 351000–352000
# Inserted rows 352000–353000
# Inserted rows 353000–354000
# Inserted rows 354000–355000
# Inserted rows 355000–356000
# Inserted rows 356000–357000
# Inserted rows 357000–358000
# Inserted rows 358000–359000
# Inserted rows 359000–360000
# Inserted rows 360000–361000
# Inserted rows 361000–362000
# Inserted rows 362000–363000
# Inserted rows 363000–364000
# Inserted rows 364000–365000
# Inserted rows 365000–366000
# Inserted rows 366000–367000
# Inserted rows 367000–368000
# Inserted rows 368000–369000
# Inserted rows 369000–370000
# Inserted rows 370000–371000
# Inserted rows 371000–372000
# Inserted rows 372000–373000
# Inserted rows 373000–374000
# Inserted rows 374000–375000
# Inserted rows 375000–376000
# Inserted rows 376000–377000
# Inserted rows 377000–378000
# Inserted rows 378000–379000
# Inserted rows 379000–380000
# Inserted rows 380000–381000
# Inserted rows 381000–382000
# Inserted rows 382000–383000
# Inserted rows 383000–384000
# Inserted rows 384000–385000
# Inserted rows 385000–386000
# Inserted rows 386000–387000
# Inserted rows 387000–388000
# Inserted rows 388000–389000
# Inserted rows 389000–390000
# Inserted rows 390000–391000
# Inserted rows 391000–392000
# Inserted rows 392000–393000
# Inserted rows 393000–394000
# Inserted rows 394000–395000
# Inserted rows 395000–396000
# Inserted rows 396000–397000
# Inserted rows 397000–398000
# Inserted rows 398000–399000
# Inserted rows 399000–400000
# Inserted rows 400000–401000
# Inserted rows 401000–402000
# Inserted rows 402000–403000
# Inserted rows 403000–404000
# Inserted rows 404000–405000
# Inserted rows 405000–406000
# Inserted rows 406000–407000
# Inserted rows 407000–408000
# Inserted rows 408000–409000
# Inserted rows 409000–410000
# Inserted rows 410000–411000
# Inserted rows 411000–412000
# Inserted rows 412000–413000
# Inserted rows 413000–414000
# Inserted rows 414000–415000
# Inserted rows 415000–416000
# Inserted rows 416000–417000
# Inserted rows 417000–418000
# Inserted rows 418000–419000
# Inserted rows 419000–420000
# Inserted rows 420000–421000
# Inserted rows 421000–422000
# Inserted rows 422000–423000
# Inserted rows 423000–424000
# Inserted rows 424000–425000
# Inserted rows 425000–426000
# Inserted rows 426000–427000
# Inserted rows 427000–428000
# Inserted rows 428000–429000
# Inserted rows 429000–430000
# Inserted rows 430000–431000
# Inserted rows 431000–432000
# Inserted rows 432000–433000
# Inserted rows 433000–434000
# Inserted rows 434000–435000
# Inserted rows 435000–436000
# Inserted rows 436000–437000
# Inserted rows 437000–438000
# Inserted rows 438000–439000
# Inserted rows 439000–440000
# Inserted rows 440000–441000
# Inserted rows 441000–442000
# Inserted rows 442000–443000
# Inserted rows 443000–444000
# Inserted rows 444000–445000
# Inserted rows 445000–446000
# Inserted rows 446000–447000
# Inserted rows 447000–448000
# Inserted rows 448000–449000
# Inserted rows 449000–450000
# Inserted rows 450000–451000
# Inserted rows 451000–452000
# Inserted rows 452000–453000
# Inserted rows 453000–454000
# Inserted rows 454000–455000
# Inserted rows 455000–456000
# Inserted rows 456000–457000
# Inserted rows 457000–458000
# Inserted rows 458000–459000
# Inserted rows 459000–460000
# Inserted rows 460000–461000
# Inserted rows 461000–462000
# Inserted rows 462000–463000
# Inserted rows 463000–464000
# Inserted rows 464000–465000
# Inserted rows 465000–466000
# Inserted rows 466000–467000
# Inserted rows 467000–468000
# Inserted rows 468000–469000
# Inserted rows 469000–470000
# Inserted rows 470000–471000
# Inserted rows 471000–472000
# Inserted rows 472000–473000
# Inserted rows 473000–474000
# Inserted rows 474000–475000
# Inserted rows 475000–476000
# Inserted rows 476000–477000
# Inserted rows 477000–478000
# Inserted rows 478000–479000
# Inserted rows 479000–480000
# Inserted rows 480000–481000
# Inserted rows 481000–482000
# Inserted rows 482000–483000
# Inserted rows 483000–484000
# Inserted rows 484000–485000
# Inserted rows 485000–486000
# Inserted rows 486000–487000
# Inserted rows 487000–488000
# Inserted rows 488000–489000
# Inserted rows 489000–490000
# Inserted rows 490000–491000
# Inserted rows 491000–492000
# Inserted rows 492000–493000
# Inserted rows 493000–494000
# Inserted rows 494000–495000
# Inserted rows 495000–496000
# Inserted rows 496000–497000
# Inserted rows 497000–498000
# Inserted rows 498000–499000
# Inserted rows 499000–500000
# Inserted rows 500000–501000
# Inserted rows 501000–502000
# Inserted rows 502000–503000
# Inserted rows 503000–504000
# Inserted rows 504000–505000
# Inserted rows 505000–506000
# Inserted rows 506000–507000
# Inserted rows 507000–508000
# Inserted rows 508000–509000
# Inserted rows 509000–510000
# Inserted rows 510000–511000
# Inserted rows 511000–512000
# Inserted rows 512000–513000
# Inserted rows 513000–514000
# Inserted rows 514000–515000
# Inserted rows 515000–516000
# Inserted rows 516000–517000
# Inserted rows 517000–518000
# Inserted rows 518000–519000
# Inserted rows 519000–520000
# Inserted rows 520000–521000
# Inserted rows 521000–522000
# Inserted rows 522000–523000
# Inserted rows 523000–524000
# Inserted rows 524000–525000
# Inserted rows 525000–526000
# Inserted rows 526000–527000
# Inserted rows 527000–528000
# Inserted rows 528000–529000
# Inserted rows 529000–530000
# Inserted rows 530000–531000
# Inserted rows 531000–532000
# Inserted rows 532000–533000
# Inserted rows 533000–534000
# Inserted rows 534000–535000
# Inserted rows 535000–536000
# Inserted rows 536000–537000
# Inserted rows 537000–538000
# Inserted rows 538000–539000
# Inserted rows 539000–540000
# Inserted rows 540000–541000
# Inserted rows 541000–542000
# Inserted rows 542000–543000
# Inserted rows 543000–544000
# Inserted rows 544000–545000
# Inserted rows 545000–546000
# Inserted rows 546000–547000
# Inserted rows 547000–548000
# Inserted rows 548000–549000
# Inserted rows 549000–550000
# Inserted rows 550000–551000
# Inserted rows 551000–552000
# Inserted rows 552000–553000
# Inserted rows 553000–554000
# Inserted rows 554000–555000
# Inserted rows 555000–556000
# Inserted rows 556000–557000
# Inserted rows 557000–558000
# Inserted rows 558000–559000
# Inserted rows 559000–560000
# Inserted rows 560000–561000
# Inserted rows 561000–562000
# Inserted rows 562000–563000
# Inserted rows 563000–564000
# Inserted rows 564000–565000
# Inserted rows 565000–566000
# Inserted rows 566000–567000
# Inserted rows 567000–568000
# Inserted rows 568000–569000
# Inserted rows 569000–570000
# Inserted rows 570000–571000
# Inserted rows 571000–572000
# Inserted rows 572000–573000
# Inserted rows 573000–574000
# Inserted rows 574000–575000
# Inserted rows 575000–576000
# Inserted rows 576000–577000
# Inserted rows 577000–578000
# Inserted rows 578000–579000
# Inserted rows 579000–580000
# Inserted rows 580000–581000
# Inserted rows 581000–582000
# Inserted rows 582000–583000
# Inserted rows 583000–584000
# Inserted rows 584000–585000
# Inserted rows 585000–586000
# Inserted rows 586000–587000
# Inserted rows 587000–588000
# Inserted rows 588000–589000
# Inserted rows 589000–590000
# Inserted rows 590000–591000
# Inserted rows 591000–592000
# Inserted rows 592000–593000
# Inserted rows 593000–594000
# Inserted rows 594000–595000
# Inserted rows 595000–596000
# Inserted rows 596000–597000
# Inserted rows 597000–598000
# Inserted rows 598000–599000
# Inserted rows 599000–600000
# Inserted rows 600000–601000
# Inserted rows 601000–602000
# Inserted rows 602000–603000
# Inserted rows 603000–604000
# Inserted rows 604000–605000
# Inserted rows 605000–606000
# Inserted rows 606000–607000
# Inserted rows 607000–608000
# Inserted rows 608000–609000
# Inserted rows 609000–610000
# Inserted rows 610000–611000
# Inserted rows 611000–612000
# Inserted rows 612000–613000
# Inserted rows 613000–614000
# Inserted rows 614000–615000
# Inserted rows 615000–616000
# Inserted rows 616000–617000
# Inserted rows 617000–618000
# Inserted rows 618000–619000
# Inserted rows 619000–620000
# Inserted rows 620000–621000
# Inserted rows 621000–622000
# Inserted rows 622000–623000
# Inserted rows 623000–624000
# Inserted rows 624000–625000
# Inserted rows 625000–626000
# Inserted rows 626000–627000
# Inserted rows 627000–628000
# Inserted rows 628000–629000
# Inserted rows 629000–630000
# Inserted rows 630000–631000
# Inserted rows 631000–632000
# Inserted rows 632000–633000
# Inserted rows 633000–634000
# Inserted rows 634000–635000
# Inserted rows 635000–636000
# Inserted rows 636000–637000
# Inserted rows 637000–638000
# Inserted rows 638000–639000
# Inserted rows 639000–640000
# Inserted rows 640000–641000
# Inserted rows 641000–642000
# Inserted rows 642000–643000
# Inserted rows 643000–644000
# Inserted rows 644000–645000
# Inserted rows 645000–646000
# Inserted rows 646000–647000
# Inserted rows 647000–648000
# Inserted rows 648000–649000
# Inserted rows 649000–650000
# Inserted rows 650000–651000
# Inserted rows 651000–652000
# Inserted rows 652000–653000
# Inserted rows 653000–654000
# Inserted rows 654000–655000
# Inserted rows 655000–656000
# Inserted rows 656000–657000
# Inserted rows 657000–658000
# Inserted rows 658000–659000
# Inserted rows 659000–660000
# Inserted rows 660000–661000
# Inserted rows 661000–662000
# Inserted rows 662000–663000
# Inserted rows 663000–664000
# Inserted rows 664000–665000
# Inserted rows 665000–666000
# Inserted rows 666000–667000
# Inserted rows 667000–668000
# Inserted rows 668000–669000
# Inserted rows 669000–670000
# Inserted rows 670000–671000
# Inserted rows 671000–672000
# Inserted rows 672000–673000
# Inserted rows 673000–674000
# Inserted rows 674000–675000
# Inserted rows 675000–676000
# Inserted rows 676000–677000
# Inserted rows 677000–678000
# Inserted rows 678000–679000
# Inserted rows 679000–680000
# Inserted rows 680000–681000
# Inserted rows 681000–682000
# Inserted rows 682000–683000
# Inserted rows 683000–684000
# Inserted rows 684000–685000
# Inserted rows 685000–686000
# Inserted rows 686000–687000
# Inserted rows 687000–688000
# Inserted rows 688000–689000
# Inserted rows 689000–690000
# Inserted rows 690000–691000
# Inserted rows 691000–692000
# Inserted rows 692000–693000
# Inserted rows 693000–694000
# Inserted rows 694000–695000
# Inserted rows 695000–696000
# Inserted rows 696000–697000
# Inserted rows 697000–698000
# Inserted rows 698000–699000
# Inserted rows 699000–700000
# Inserted rows 700000–701000
# Inserted rows 701000–702000
# Inserted rows 702000–703000
# Inserted rows 703000–704000
# Inserted rows 704000–705000
# Inserted rows 705000–706000
# Inserted rows 706000–707000
# Inserted rows 707000–708000
# Inserted rows 708000–709000
# Inserted rows 709000–710000
# Inserted rows 710000–711000
# Inserted rows 711000–712000
# Inserted rows 712000–713000
# Inserted rows 713000–714000
# Inserted rows 714000–715000
# Inserted rows 715000–716000
# Inserted rows 716000–717000
# Inserted rows 717000–718000
# Inserted rows 718000–719000
# Inserted rows 719000–720000
# Inserted rows 720000–721000
# Inserted rows 721000–722000
# Inserted rows 722000–723000
# Inserted rows 723000–724000
# Inserted rows 724000–725000
# Inserted rows 725000–726000
# Inserted rows 726000–727000
# Inserted rows 727000–728000
# Inserted rows 728000–729000
# Inserted rows 729000–730000
# Inserted rows 730000–731000
# Inserted rows 731000–732000
# Inserted rows 732000–733000
# Inserted rows 733000–734000
# Inserted rows 734000–735000
# Inserted rows 735000–736000
# Inserted rows 736000–737000
# Inserted rows 737000–738000
# Inserted rows 738000–739000
# Inserted rows 739000–740000
# Inserted rows 740000–741000
# Inserted rows 741000–742000
# Inserted rows 742000–743000
# Inserted rows 743000–744000
# Inserted rows 744000–745000
# Inserted rows 745000–746000
# Inserted rows 746000–747000
# Inserted rows 747000–748000
# Inserted rows 748000–749000
# Inserted rows 749000–750000
# Inserted rows 750000–751000
# Inserted rows 751000–752000
# Inserted rows 752000–753000
# Inserted rows 753000–754000
# Inserted rows 754000–755000
# Inserted rows 755000–756000
# Inserted rows 756000–757000
# Inserted rows 757000–758000
# Inserted rows 758000–759000
# Inserted rows 759000–760000
# Inserted rows 760000–761000
# Inserted rows 761000–762000
# Inserted rows 762000–763000
# Inserted rows 763000–764000
# Inserted rows 764000–765000
# Inserted rows 765000–766000
# Inserted rows 766000–767000
# Inserted rows 767000–768000
# Inserted rows 768000–769000
# Inserted rows 769000–770000
# Inserted rows 770000–771000
# Inserted rows 771000–772000
# Inserted rows 772000–773000
# Inserted rows 773000–774000
# Inserted rows 774000–775000
# Inserted rows 775000–776000
# Inserted rows 776000–777000
# Inserted rows 777000–778000
# Inserted rows 778000–779000
# Inserted rows 779000–780000
# Inserted rows 780000–781000
# Inserted rows 781000–782000
# Inserted rows 782000–783000
# Inserted rows 783000–784000
# Inserted rows 784000–785000
# Inserted rows 785000–786000
# Inserted rows 786000–787000
# Inserted rows 787000–788000
# Inserted rows 788000–789000
# Inserted rows 789000–790000
# Inserted rows 790000–791000
# Inserted rows 791000–792000
# Inserted rows 792000–793000
# Inserted rows 793000–794000
# Inserted rows 794000–795000
# Inserted rows 795000–796000
# Inserted rows 796000–797000
# Inserted rows 797000–798000
# Inserted rows 798000–799000
# Inserted rows 799000–800000
# Inserted rows 800000–801000
# Inserted rows 801000–802000
# Inserted rows 802000–803000
# Inserted rows 803000–804000
# Inserted rows 804000–805000
# Inserted rows 805000–806000
# Inserted rows 806000–807000
# Inserted rows 807000–808000
# Inserted rows 808000–809000
# Inserted rows 809000–810000
# Inserted rows 810000–811000
# Inserted rows 811000–812000
# Inserted rows 812000–813000
# Inserted rows 813000–814000
# Inserted rows 814000–815000
# Inserted rows 815000–816000
# Inserted rows 816000–817000
# Inserted rows 817000–818000
# Inserted rows 818000–819000
# Inserted rows 819000–820000
# Inserted rows 820000–821000
# Inserted rows 821000–822000
# Inserted rows 822000–823000
# Inserted rows 823000–824000
# Inserted rows 824000–825000
# Inserted rows 825000–826000
# Inserted rows 826000–827000
# Inserted rows 827000–828000
# Inserted rows 828000–829000
# Inserted rows 829000–830000
# Inserted rows 830000–831000
# Inserted rows 831000–832000
# Inserted rows 832000–833000
# Inserted rows 833000–834000
# Inserted rows 834000–835000
# Inserted rows 835000–836000
# Inserted rows 836000–837000
# Inserted rows 837000–838000
# Inserted rows 838000–839000
# Inserted rows 839000–840000
# Inserted rows 840000–841000
# Inserted rows 841000–842000
# Inserted rows 842000–843000
# Inserted rows 843000–844000
# Inserted rows 844000–845000
# Inserted rows 845000–846000
# Inserted rows 846000–847000
# Inserted rows 847000–848000
# Inserted rows 848000–849000
# Inserted rows 849000–850000
# Inserted rows 850000–851000
# Inserted rows 851000–852000
# Inserted rows 852000–853000
# Inserted rows 853000–854000
# Inserted rows 854000–855000
# Inserted rows 855000–856000
# Inserted rows 856000–857000
# Inserted rows 857000–858000
# Inserted rows 858000–859000
# Inserted rows 859000–860000
# Inserted rows 860000–861000
# Inserted rows 861000–862000
# Inserted rows 862000–863000
# Inserted rows 863000–864000
# Inserted rows 864000–865000
# Inserted rows 865000–866000
# Inserted rows 866000–867000
# Inserted rows 867000–868000
# Inserted rows 868000–869000
# Inserted rows 869000–870000
# Inserted rows 870000–871000
# Inserted rows 871000–872000
# Inserted rows 872000–873000
# Inserted rows 873000–874000
# Inserted rows 874000–875000
# Inserted rows 875000–876000
# Inserted rows 876000–877000
# Inserted rows 877000–878000
# Inserted rows 878000–879000
# Inserted rows 879000–880000
# Inserted rows 880000–881000
# Inserted rows 881000–882000
# Inserted rows 882000–883000
# Inserted rows 883000–884000
# Inserted rows 884000–885000
# Inserted rows 885000–886000
# Inserted rows 886000–887000
# Inserted rows 887000–888000
# Inserted rows 888000–889000
# Inserted rows 889000–890000
# Inserted rows 890000–891000
# Inserted rows 891000–892000
# Inserted rows 892000–893000
# Inserted rows 893000–894000
# Inserted rows 894000–895000
# Inserted rows 895000–896000
# Inserted rows 896000–897000
# Inserted rows 897000–898000
# Inserted rows 898000–899000
# Inserted rows 899000–900000
# Inserted rows 900000–901000
# Inserted rows 901000–902000
# Inserted rows 902000–903000
# Inserted rows 903000–904000
# Inserted rows 904000–905000
# Inserted rows 905000–906000
# Inserted rows 906000–907000
# Inserted rows 907000–908000
# Inserted rows 908000–909000
# Inserted rows 909000–910000
# Inserted rows 910000–911000
# Inserted rows 911000–912000
# Inserted rows 912000–913000
# Inserted rows 913000–914000
# Inserted rows 914000–915000
# Inserted rows 915000–916000
# Inserted rows 916000–917000
# Inserted rows 917000–918000
# Inserted rows 918000–919000
# Inserted rows 919000–920000
# Inserted rows 920000–921000
# Inserted rows 921000–922000
# Inserted rows 922000–923000
# Inserted rows 923000–924000
# Inserted rows 924000–925000
# Inserted rows 925000–926000
# Inserted rows 926000–927000
# Inserted rows 927000–928000
# Inserted rows 928000–929000
# Inserted rows 929000–930000
# Inserted rows 930000–931000
# Inserted rows 931000–932000
# Inserted rows 932000–933000
# Inserted rows 933000–934000
# Inserted rows 934000–935000
# Inserted rows 935000–936000
# Inserted rows 936000–937000
# Inserted rows 937000–938000
# Inserted rows 938000–939000
# Inserted rows 939000–940000
# Inserted rows 940000–941000
# Inserted rows 941000–942000
# Inserted rows 942000–943000
# Inserted rows 943000–944000
# Inserted rows 944000–945000
# Inserted rows 945000–946000
# Inserted rows 946000–947000
# Inserted rows 947000–948000
# Inserted rows 948000–949000
# Inserted rows 949000–950000
# Inserted rows 950000–951000
# Inserted rows 951000–952000
# Inserted rows 952000–953000
# Inserted rows 953000–954000
# Inserted rows 954000–955000
# Inserted rows 955000–956000
# Inserted rows 956000–957000
# Inserted rows 957000–958000
# Inserted rows 958000–959000
# Inserted rows 959000–960000
# Inserted rows 960000–961000
# Inserted rows 961000–962000
# Inserted rows 962000–963000
# Inserted rows 963000–964000
# Inserted rows 964000–965000
# Inserted rows 965000–966000
# Inserted rows 966000–967000
# Inserted rows 967000–968000
# Inserted rows 968000–969000
# Inserted rows 969000–970000
# Inserted rows 970000–971000
# Inserted rows 971000–972000
# Inserted rows 972000–973000
# Inserted rows 973000–974000
# Inserted rows 974000–975000
# Inserted rows 975000–976000
# Inserted rows 976000–977000
# Inserted rows 977000–978000
# Inserted rows 978000–979000
# Inserted rows 979000–980000
# Inserted rows 980000–981000
# Inserted rows 981000–982000
# Inserted rows 982000–983000
# Inserted rows 983000–984000
# Inserted rows 984000–985000
# Inserted rows 985000–986000
# Inserted rows 986000–987000
# Inserted rows 987000–988000
# Inserted rows 988000–989000
# Inserted rows 989000–990000
# Inserted rows 990000–991000
# Inserted rows 991000–992000
# Inserted rows 992000–993000
# Inserted rows 993000–994000
# Inserted rows 994000–995000
# Inserted rows 995000–996000
# Inserted rows 996000–997000
# Inserted rows 997000–998000
# Inserted rows 998000–999000
# Inserted rows 999000–1000000
# Inserted rows 1000000–1001000
# Inserted rows 1001000–1002000
# Inserted rows 1002000–1003000
# Inserted rows 1003000–1004000
# Inserted rows 1004000–1005000
# Inserted rows 1005000–1006000
# Inserted rows 1006000–1007000
# Inserted rows 1007000–1008000
# Inserted rows 1008000–1009000
# Inserted rows 1009000–1010000
# Inserted rows 1010000–1011000
# Inserted rows 1011000–1012000
# Inserted rows 1012000–1013000
# Inserted rows 1013000–1014000
# Inserted rows 1014000–1015000
# Inserted rows 1015000–1016000
# Inserted rows 1016000–1017000
# Inserted rows 1017000–1018000
# Inserted rows 1018000–1019000
# Inserted rows 1019000–1020000
# Inserted rows 1020000–1021000
# Inserted rows 1021000–1022000
# Inserted rows 1022000–1023000
# Inserted rows 1023000–1024000
# Inserted rows 1024000–1025000
# Inserted rows 1025000–1026000
# Inserted rows 1026000–1027000
# Inserted rows 1027000–1028000
# Inserted rows 1028000–1029000
# Inserted rows 1029000–1030000
# Inserted rows 1030000–1031000
# Inserted rows 1031000–1032000
# Inserted rows 1032000–1033000
# Inserted rows 1033000–1034000
# Inserted rows 1034000–1035000
# Inserted rows 1035000–1036000
# Inserted rows 1036000–1037000
# Inserted rows 1037000–1038000
# Inserted rows 1038000–1039000
# Inserted rows 1039000–1040000
# Inserted rows 1040000–1041000
# Inserted rows 1041000–1042000
# Inserted rows 1042000–1043000
# Inserted rows 1043000–1044000
# Inserted rows 1044000–1045000
# Inserted rows 1045000–1046000
# Inserted rows 1046000–1047000
# Inserted rows 1047000–1048000
# Inserted rows 1048000–1049000
# Inserted rows 1049000–1050000
# Inserted rows 1050000–1051000
# Inserted rows 1051000–1052000
# Inserted rows 1052000–1053000
# Inserted rows 1053000–1054000
# Inserted rows 1054000–1055000
# Inserted rows 1055000–1056000
# Inserted rows 1056000–1057000
# Inserted rows 1057000–1058000
# Inserted rows 1058000–1059000
# Inserted rows 1059000–1060000
# Inserted rows 1060000–1061000
# Inserted rows 1061000–1062000
# Inserted rows 1062000–1063000
# Inserted rows 1063000–1064000
# Inserted rows 1064000–1065000
# Inserted rows 1065000–1066000
# Inserted rows 1066000–1067000
# Inserted rows 1067000–1068000
# Inserted rows 1068000–1069000
# Inserted rows 1069000–1070000
# Inserted rows 1070000–1071000
# Inserted rows 1071000–1072000
# Inserted rows 1072000–1073000
# Inserted rows 1073000–1074000
# Inserted rows 1074000–1075000
# Inserted rows 1075000–1076000
# Inserted rows 1076000–1077000
# Inserted rows 1077000–1078000
# Inserted rows 1078000–1079000
# Inserted rows 1079000–1080000
# Inserted rows 1080000–1081000
# Inserted rows 1081000–1082000
# Inserted rows 1082000–1083000
# Inserted rows 1083000–1084000
# Inserted rows 1084000–1085000
# Inserted rows 1085000–1086000
# Inserted rows 1086000–1087000
# Inserted rows 1087000–1088000
# Inserted rows 1088000–1089000
# Inserted rows 1089000–1090000
# Inserted rows 1090000–1091000
# Inserted rows 1091000–1092000
# Inserted rows 1092000–1093000
# Inserted rows 1093000–1094000
# Inserted rows 1094000–1095000
# Inserted rows 1095000–1096000
# Inserted rows 1096000–1097000
# Inserted rows 1097000–1098000
# Inserted rows 1098000–1099000
# Inserted rows 1099000–1100000
# Inserted rows 1100000–1101000
# Inserted rows 1101000–1102000
# Inserted rows 1102000–1103000
# Inserted rows 1103000–1104000
# Inserted rows 1104000–1105000
# Inserted rows 1105000–1106000
# Inserted rows 1106000–1107000
# Inserted rows 1107000–1108000
# Inserted rows 1108000–1109000
# Inserted rows 1109000–1110000
# Inserted rows 1110000–1111000
# Inserted rows 1111000–1112000
# Inserted rows 1112000–1113000
# Inserted rows 1113000–1114000
# Inserted rows 1114000–1115000
# Inserted rows 1115000–1116000
# Inserted rows 1116000–1117000
# Inserted rows 1117000–1118000
# Inserted rows 1118000–1119000
# Inserted rows 1119000–1120000
# Inserted rows 1120000–1121000
# Inserted rows 1121000–1122000
# Inserted rows 1122000–1123000
# Inserted rows 1123000–1124000
# Inserted rows 1124000–1125000
# Inserted rows 1125000–1126000
# Inserted rows 1126000–1127000
# Inserted rows 1127000–1128000
# Inserted rows 1128000–1129000
# Inserted rows 1129000–1130000
# Inserted rows 1130000–1131000
# Inserted rows 1131000–1132000
# Inserted rows 1132000–1133000
# Inserted rows 1133000–1134000
# Inserted rows 1134000–1135000
# Inserted rows 1135000–1136000
# Inserted rows 1136000–1137000
# Inserted rows 1137000–1138000
# Inserted rows 1138000–1139000
# Inserted rows 1139000–1140000
# Inserted rows 1140000–1141000
# Inserted rows 1141000–1142000
# Inserted rows 1142000–1143000
# Inserted rows 1143000–1144000
# Inserted rows 1144000–1145000
# Inserted rows 1145000–1146000
# Inserted rows 1146000–1147000
# Inserted rows 1147000–1148000
# Inserted rows 1148000–1149000
# Inserted rows 1149000–1150000
# Inserted rows 1150000–1151000
# Inserted rows 1151000–1152000
# Inserted rows 1152000–1153000
# Inserted rows 1153000–1154000
# Inserted rows 1154000–1155000
# Inserted rows 1155000–1156000
# Inserted rows 1156000–1157000
# Inserted rows 1157000–1158000
# Inserted rows 1158000–1159000
# Inserted rows 1159000–1160000
# Inserted rows 1160000–1161000
# Inserted rows 1161000–1162000
# Inserted rows 1162000–1163000
# Inserted rows 1163000–1164000
# Inserted rows 1164000–1165000
# Inserted rows 1165000–1166000
# Inserted rows 1166000–1167000
# Inserted rows 1167000–1168000
# Inserted rows 1168000–1169000
# Inserted rows 1169000–1170000
# Inserted rows 1170000–1171000
# Inserted rows 1171000–1172000
# Inserted rows 1172000–1173000
# Inserted rows 1173000–1174000
# Inserted rows 1174000–1175000
# Inserted rows 1175000–1176000
# Inserted rows 1176000–1177000
# Inserted rows 1177000–1178000
# Inserted rows 1178000–1179000
# Inserted rows 1179000–1180000
# Inserted rows 1180000–1181000
# Inserted rows 1181000–1182000
# Inserted rows 1182000–1183000
# Inserted rows 1183000–1184000
# Inserted rows 1184000–1185000
# Inserted rows 1185000–1186000
# Inserted rows 1186000–1187000
# Inserted rows 1187000–1188000
# Inserted rows 1188000–1189000
# Inserted rows 1189000–1190000
# Inserted rows 1190000–1191000
# Inserted rows 1191000–1192000
# Inserted rows 1192000–1193000
# Inserted rows 1193000–1194000
# Inserted rows 1194000–1195000
# Inserted rows 1195000–1196000
# Inserted rows 1196000–1197000
# Inserted rows 1197000–1198000
# Inserted rows 1198000–1199000
# Inserted rows 1199000–1200000
# Inserted rows 1200000–1201000
# Inserted rows 1201000–1202000
# Inserted rows 1202000–1203000
# Inserted rows 1203000–1204000
# Inserted rows 1204000–1205000
# Inserted rows 1205000–1206000
# Inserted rows 1206000–1207000
# Inserted rows 1207000–1208000
# Inserted rows 1208000–1209000
# Inserted rows 1209000–1210000
# Inserted rows 1210000–1211000
# Inserted rows 1211000–1212000
# Inserted rows 1212000–1213000
# Inserted rows 1213000–1214000
# Inserted rows 1214000–1215000
# Inserted rows 1215000–1216000
# Inserted rows 1216000–1217000
# Inserted rows 1217000–1218000
# Inserted rows 1218000–1219000
# Inserted rows 1219000–1220000
# Inserted rows 1220000–1221000
# Inserted rows 1221000–1222000
# Inserted rows 1222000–1223000
# Inserted rows 1223000–1224000
# Inserted rows 1224000–1225000
# Inserted rows 1225000–1226000
# Inserted rows 1226000–1227000
# Inserted rows 1227000–1228000
# Inserted rows 1228000–1229000
# Inserted rows 1229000–1230000
# Inserted rows 1230000–1231000
# Inserted rows 1231000–1232000
# Inserted rows 1232000–1233000
# Inserted rows 1233000–1234000
# Inserted rows 1234000–1235000
# Inserted rows 1235000–1236000
# Inserted rows 1236000–1237000
# Inserted rows 1237000–1238000
# Inserted rows 1238000–1239000
# Inserted rows 1239000–1240000
# Inserted rows 1240000–1241000
# Inserted rows 1241000–1242000
# Inserted rows 1242000–1243000
# Inserted rows 1243000–1244000
# Inserted rows 1244000–1245000
# Inserted rows 1245000–1246000
# Inserted rows 1246000–1247000
# Inserted rows 1247000–1248000
# Inserted rows 1248000–1249000
# Inserted rows 1249000–1250000
# Inserted rows 1250000–1251000
# Inserted rows 1251000–1252000
# Inserted rows 1252000–1253000
# Inserted rows 1253000–1254000
# Inserted rows 1254000–1255000
# Inserted rows 1255000–1256000
# Inserted rows 1256000–1257000
# Inserted rows 1257000–1258000
# Inserted rows 1258000–1259000
# Inserted rows 1259000–1260000
# Inserted rows 1260000–1261000
# Inserted rows 1261000–1262000
# Inserted rows 1262000–1263000
# Inserted rows 1263000–1264000
# Inserted rows 1264000–1265000
# Inserted rows 1265000–1266000
# Inserted rows 1266000–1267000
# Inserted rows 1267000–1268000
# Inserted rows 1268000–1269000
# Inserted rows 1269000–1270000
# Inserted rows 1270000–1271000
# Inserted rows 1271000–1272000
# Inserted rows 1272000–1273000
# Inserted rows 1273000–1274000
# Inserted rows 1274000–1275000
# Inserted rows 1275000–1276000
# Inserted rows 1276000–1277000
# Inserted rows 1277000–1278000
# Inserted rows 1278000–1279000
# Inserted rows 1279000–1280000
# Inserted rows 1280000–1281000
# Inserted rows 1281000–1282000
# Inserted rows 1282000–1283000
# Inserted rows 1283000–1284000
# Inserted rows 1284000–1285000
# Inserted rows 1285000–1286000
# Inserted rows 1286000–1287000
# Inserted rows 1287000–1288000
# Inserted rows 1288000–1289000
# Inserted rows 1289000–1290000
# Inserted rows 1290000–1291000
# Inserted rows 1291000–1292000
# Inserted rows 1292000–1293000
# Inserted rows 1293000–1294000
# Inserted rows 1294000–1295000
# Inserted rows 1295000–1296000
# Inserted rows 1296000–1297000
# Inserted rows 1297000–1298000
# Inserted rows 1298000–1299000
# Inserted rows 1299000–1300000
# Inserted rows 1300000–1301000
# Inserted rows 1301000–1302000
# Inserted rows 1302000–1303000
# Inserted rows 1303000–1304000
# Inserted rows 1304000–1305000
# Inserted rows 1305000–1306000
# Inserted rows 1306000–1307000
# Inserted rows 1307000–1308000
# Inserted rows 1308000–1309000
# Inserted rows 1309000–1310000
# Inserted rows 1310000–1311000
# Inserted rows 1311000–1312000
# Inserted rows 1312000–1313000
# Inserted rows 1313000–1314000
# Inserted rows 1314000–1315000
# Inserted rows 1315000–1316000
# Inserted rows 1316000–1317000
# Inserted rows 1317000–1318000
# Inserted rows 1318000–1319000
# Inserted rows 1319000–1320000
# Inserted rows 1320000–1321000
# Inserted rows 1321000–1322000
# Inserted rows 1322000–1323000
# Inserted rows 1323000–1324000
# Inserted rows 1324000–1325000
# Inserted rows 1325000–1326000
# Inserted rows 1326000–1327000
# Inserted rows 1327000–1328000
# Inserted rows 1328000–1329000
# Inserted rows 1329000–1330000
# Inserted rows 1330000–1331000
# Inserted rows 1331000–1332000
# Inserted rows 1332000–1333000
# Inserted rows 1333000–1334000
# Inserted rows 1334000–1335000
# Inserted rows 1335000–1336000
# Inserted rows 1336000–1337000
# Inserted rows 1337000–1338000
# Inserted rows 1338000–1339000
# Inserted rows 1339000–1340000
# Inserted rows 1340000–1341000
# Inserted rows 1341000–1342000
# Inserted rows 1342000–1343000
# Inserted rows 1343000–1344000
# Inserted rows 1344000–1345000
# Inserted rows 1345000–1346000
# Inserted rows 1346000–1347000
# Inserted rows 1347000–1348000
# Inserted rows 1348000–1349000
# Inserted rows 1349000–1350000
# Inserted rows 1350000–1351000
# Inserted rows 1351000–1352000
# Inserted rows 1352000–1353000
# Inserted rows 1353000–1354000
# Inserted rows 1354000–1355000
# Inserted rows 1355000–1356000
# Inserted rows 1356000–1357000
# Inserted rows 1357000–1358000
# Inserted rows 1358000–1359000
# Inserted rows 1359000–1360000
# Inserted rows 1360000–1361000
# Inserted rows 1361000–1362000
# Inserted rows 1362000–1363000
# Inserted rows 1363000–1364000
# Inserted rows 1364000–1365000
# Inserted rows 1365000–1366000
# Inserted rows 1366000–1367000
# Inserted rows 1367000–1368000
# Inserted rows 1368000–1369000
# Inserted rows 1369000–1370000
# Inserted rows 1370000–1371000
# Inserted rows 1371000–1372000
# Inserted rows 1372000–1373000
# Inserted rows 1373000–1374000
# Inserted rows 1374000–1375000
# Inserted rows 1375000–1376000
# Inserted rows 1376000–1377000
# Inserted rows 1377000–1378000
# Inserted rows 1378000–1379000
# Inserted rows 1379000–1380000
# Inserted rows 1380000–1381000
# Inserted rows 1381000–1382000
# Inserted rows 1382000–1383000
# Inserted rows 1383000–1384000
# Inserted rows 1384000–1385000
# Inserted rows 1385000–1386000
# Inserted rows 1386000–1387000
# Inserted rows 1387000–1388000
# Inserted rows 1388000–1389000
# Inserted rows 1389000–1390000
# Inserted rows 1390000–1391000
# Inserted rows 1391000–1392000
# Inserted rows 1392000–1393000
# Inserted rows 1393000–1394000
# Inserted rows 1394000–1395000
# Inserted rows 1395000–1396000
# Inserted rows 1396000–1397000
# Inserted rows 1397000–1398000
# Inserted rows 1398000–1399000
# Inserted rows 1399000–1400000
# Inserted rows 1400000–1401000
# Inserted rows 1401000–1402000
# Inserted rows 1402000–1403000
# Inserted rows 1403000–1404000
# Inserted rows 1404000–1405000
# Inserted rows 1405000–1406000
# Inserted rows 1406000–1407000
# Inserted rows 1407000–1408000
# Inserted rows 1408000–1409000
# Inserted rows 1409000–1410000
# Inserted rows 1410000–1411000
# Inserted rows 1411000–1412000
# Inserted rows 1412000–1413000
# Inserted rows 1413000–1414000
# Inserted rows 1414000–1415000
# Inserted rows 1415000–1416000
# Inserted rows 1416000–1417000
# Inserted rows 1417000–1418000
# Inserted rows 1418000–1419000
# Inserted rows 1419000–1420000
# Inserted rows 1420000–1421000
# Inserted rows 1421000–1422000
# Inserted rows 1422000–1423000
# Inserted rows 1423000–1424000
# Inserted rows 1424000–1425000
# Inserted rows 1425000–1426000
# Inserted rows 1426000–1427000
# Inserted rows 1427000–1428000
# Inserted rows 1428000–1429000
# Inserted rows 1429000–1430000
# Inserted rows 1430000–1431000
# Inserted rows 1431000–1432000
# Inserted rows 1432000–1433000
# Inserted rows 1433000–1434000
# Inserted rows 1434000–1435000
# Inserted rows 1435000–1436000
# Inserted rows 1436000–1437000
# Inserted rows 1437000–1438000
# Inserted rows 1438000–1439000
# Inserted rows 1439000–1440000
# Inserted rows 1440000–1441000
# Inserted rows 1441000–1442000
# Inserted rows 1442000–1443000
# Inserted rows 1443000–1444000
# Inserted rows 1444000–1445000
# Inserted rows 1445000–1446000
# Inserted rows 1446000–1447000
# Inserted rows 1447000–1448000
# Inserted rows 1448000–1449000
# Inserted rows 1449000–1450000
# Inserted rows 1450000–1451000
# Inserted rows 1451000–1452000
# Inserted rows 1452000–1453000
# Inserted rows 1453000–1454000
# Inserted rows 1454000–1455000
# Inserted rows 1455000–1456000
# Inserted rows 1456000–1457000
# Inserted rows 1457000–1458000
# Inserted rows 1458000–1459000
# Inserted rows 1459000–1460000
# Inserted rows 1460000–1461000
# Inserted rows 1461000–1462000
# Inserted rows 1462000–1463000
# Inserted rows 1463000–1464000
# Inserted rows 1464000–1465000
# Inserted rows 1465000–1466000
# Inserted rows 1466000–1467000
# Inserted rows 1467000–1468000
# Inserted rows 1468000–1469000
# Inserted rows 1469000–1470000
# Inserted rows 1470000–1471000
# Inserted rows 1471000–1472000
# Inserted rows 1472000–1473000
# Inserted rows 1473000–1474000
# Inserted rows 1474000–1475000
# Inserted rows 1475000–1476000
# Inserted rows 1476000–1477000
# Inserted rows 1477000–1478000
# Inserted rows 1478000–1479000
# Inserted rows 1479000–1480000
# Inserted rows 1480000–1481000
# Inserted rows 1481000–1482000
# Inserted rows 1482000–1483000
# Inserted rows 1483000–1484000
# Inserted rows 1484000–1485000
# Inserted rows 1485000–1486000
# Inserted rows 1486000–1487000
# Inserted rows 1487000–1488000
# Inserted rows 1488000–1489000
# Inserted rows 1489000–1490000
# Inserted rows 1490000–1491000
# Inserted rows 1491000–1492000
# Inserted rows 1492000–1493000
# Inserted rows 1493000–1494000
# Inserted rows 1494000–1495000
# Inserted rows 1495000–1496000
# Inserted rows 1496000–1497000
# Inserted rows 1497000–1498000
# Inserted rows 1498000–1499000
# Inserted rows 1499000–1500000
# Inserted rows 1500000–1501000
# Inserted rows 1501000–1502000
# Inserted rows 1502000–1503000
# Inserted rows 1503000–1504000
# Inserted rows 1504000–1505000
# Inserted rows 1505000–1506000
# Inserted rows 1506000–1507000
# Inserted rows 1507000–1508000
# Inserted rows 1508000–1509000
# Inserted rows 1509000–1510000
# Inserted rows 1510000–1511000
# Inserted rows 1511000–1512000
# Inserted rows 1512000–1513000
# Inserted rows 1513000–1514000
# Inserted rows 1514000–1515000
# Inserted rows 1515000–1516000
# Inserted rows 1516000–1517000
# Inserted rows 1517000–1518000
# Inserted rows 1518000–1519000
# Inserted rows 1519000–1520000
# Inserted rows 1520000–1521000
# Inserted rows 1521000–1522000
# Inserted rows 1522000–1523000
# Inserted rows 1523000–1524000
# Inserted rows 1524000–1525000
# Inserted rows 1525000–1526000
# Inserted rows 1526000–1527000
# Inserted rows 1527000–1528000
# Inserted rows 1528000–1529000
# Inserted rows 1529000–1530000
# Inserted rows 1530000–1531000
# Inserted rows 1531000–1532000
# Inserted rows 1532000–1533000
# Inserted rows 1533000–1534000
# Inserted rows 1534000–1535000
# Inserted rows 1535000–1536000
# Inserted rows 1536000–1537000
# Inserted rows 1537000–1538000
# Inserted rows 1538000–1539000
# Inserted rows 1539000–1540000
# Inserted rows 1540000–1541000
# Inserted rows 1541000–1542000
# Inserted rows 1542000–1543000
# Inserted rows 1543000–1544000
# Inserted rows 1544000–1545000
# Inserted rows 1545000–1546000
# Inserted rows 1546000–1547000
# Inserted rows 1547000–1548000
# Inserted rows 1548000–1549000
# Inserted rows 1549000–1550000
# Inserted rows 1550000–1551000
# Inserted rows 1551000–1552000
# Inserted rows 1552000–1553000
# Inserted rows 1553000–1554000
# Inserted rows 1554000–1555000
# Inserted rows 1555000–1556000
# Inserted rows 1556000–1557000
# Inserted rows 1557000–1558000
# Inserted rows 1558000–1559000
# Inserted rows 1559000–1560000
# Inserted rows 1560000–1561000
# Inserted rows 1561000–1562000
# Inserted rows 1562000–1563000
# Inserted rows 1563000–1564000
# Inserted rows 1564000–1565000
# Inserted rows 1565000–1566000
# Inserted rows 1566000–1567000
# Inserted rows 1567000–1568000
# Inserted rows 1568000–1569000
# Inserted rows 1569000–1570000
# Inserted rows 1570000–1571000
# Inserted rows 1571000–1572000
# Inserted rows 1572000–1573000
# Inserted rows 1573000–1574000
# Inserted rows 1574000–1575000
# Inserted rows 1575000–1576000
# Inserted rows 1576000–1577000
# Inserted rows 1577000–1578000
# Inserted rows 1578000–1579000
# Inserted rows 1579000–1580000
# Inserted rows 1580000–1581000
# Inserted rows 1581000–1582000
# Inserted rows 1582000–1583000
# Inserted rows 1583000–1584000
# Inserted rows 1584000–1585000
# Inserted rows 1585000–1586000
# Inserted rows 1586000–1587000
# Inserted rows 1587000–1588000
# Inserted rows 1588000–1589000
# Inserted rows 1589000–1590000
# Inserted rows 1590000–1591000
# Inserted rows 1591000–1592000
# Inserted rows 1592000–1593000
# Inserted rows 1593000–1594000
# Inserted rows 1594000–1595000
# Inserted rows 1595000–1596000
# Inserted rows 1596000–1597000
# Inserted rows 1597000–1598000
# Inserted rows 1598000–1599000
# Inserted rows 1599000–1600000
# Inserted rows 1600000–1601000
# Inserted rows 1601000–1602000
# Inserted rows 1602000–1603000
# Inserted rows 1603000–1604000
# Inserted rows 1604000–1605000
# Inserted rows 1605000–1606000
# Inserted rows 1606000–1607000
# Inserted rows 1607000–1608000
# Inserted rows 1608000–1609000
# Inserted rows 1609000–1610000
# Inserted rows 1610000–1611000
# Inserted rows 1611000–1612000
# Inserted rows 1612000–1613000
# Inserted rows 1613000–1614000
# Inserted rows 1614000–1615000
# Inserted rows 1615000–1616000
# Inserted rows 1616000–1617000
# Inserted rows 1617000–1618000
# Inserted rows 1618000–1619000
# Inserted rows 1619000–1620000
# Inserted rows 1620000–1621000
# Inserted rows 1621000–1622000
# Inserted rows 1622000–1623000
# Inserted rows 1623000–1624000
# Inserted rows 1624000–1625000
# Inserted rows 1625000–1626000
# Inserted rows 1626000–1627000
# Inserted rows 1627000–1628000
# Inserted rows 1628000–1629000
# Inserted rows 1629000–1630000
# Inserted rows 1630000–1631000
# Inserted rows 1631000–1632000
# Inserted rows 1632000–1633000
# Inserted rows 1633000–1634000
# Inserted rows 1634000–1635000
# Inserted rows 1635000–1636000
# Inserted rows 1636000–1637000
# Inserted rows 1637000–1638000
# Inserted rows 1638000–1639000
# Inserted rows 1639000–1640000
# Inserted rows 1640000–1641000
# Inserted rows 1641000–1642000
# Inserted rows 1642000–1643000
# Inserted rows 1643000–1644000
# Inserted rows 1644000–1645000
# Inserted rows 1645000–1646000
# Inserted rows 1646000–1647000
# Inserted rows 1647000–1648000
# Inserted rows 1648000–1649000
# Inserted rows 1649000–1650000
# Inserted rows 1650000–1651000
# Inserted rows 1651000–1652000
# Inserted rows 1652000–1653000
# Inserted rows 1653000–1654000
# Inserted rows 1654000–1655000
# Inserted rows 1655000–1656000
# Inserted rows 1656000–1657000
# Inserted rows 1657000–1658000
# Inserted rows 1658000–1659000
# Inserted rows 1659000–1660000
# Inserted rows 1660000–1661000
# Inserted rows 1661000–1662000
# Inserted rows 1662000–1663000
# Inserted rows 1663000–1664000
# Inserted rows 1664000–1665000
# Inserted rows 1665000–1666000
# Inserted rows 1666000–1667000
# Inserted rows 1667000–1668000
# Inserted rows 1668000–1669000
# Inserted rows 1669000–1670000
# Inserted rows 1670000–1671000
# Inserted rows 1671000–1672000
# Inserted rows 1672000–1673000
# Inserted rows 1673000–1674000
# Inserted rows 1674000–1675000
# Inserted rows 1675000–1676000
# Inserted rows 1676000–1677000
# Inserted rows 1677000–1678000
# Inserted rows 1678000–1679000
# Inserted rows 1679000–1680000
# Inserted rows 1680000–1681000
# Inserted rows 1681000–1682000
# Inserted rows 1682000–1683000
# Inserted rows 1683000–1684000
# Inserted rows 1684000–1685000
# Inserted rows 1685000–1686000
# Inserted rows 1686000–1687000
# Inserted rows 1687000–1688000
# Inserted rows 1688000–1689000
# Inserted rows 1689000–1690000
# Inserted rows 1690000–1691000
# Inserted rows 1691000–1692000
# Inserted rows 1692000–1693000
# Inserted rows 1693000–1694000
# Inserted rows 1694000–1695000
# Inserted rows 1695000–1696000
# Inserted rows 1696000–1697000
# Inserted rows 1697000–1698000
# Inserted rows 1698000–1699000
# Inserted rows 1699000–1700000
# Inserted rows 1700000–1701000
# Inserted rows 1701000–1702000
# Inserted rows 1702000–1703000
# Inserted rows 1703000–1704000
# Inserted rows 1704000–1705000
# Inserted rows 1705000–1706000
# Inserted rows 1706000–1707000
# Inserted rows 1707000–1708000
# Inserted rows 1708000–1709000
# Inserted rows 1709000–1710000
# Inserted rows 1710000–1711000
# Inserted rows 1711000–1712000
# Inserted rows 1712000–1713000
# Inserted rows 1713000–1714000
# Inserted rows 1714000–1715000
# Inserted rows 1715000–1716000
# Inserted rows 1716000–1717000
# Inserted rows 1717000–1718000
# Inserted rows 1718000–1719000
# Inserted rows 1719000–1720000
# Inserted rows 1720000–1721000
# Inserted rows 1721000–1722000
# Inserted rows 1722000–1723000
# Inserted rows 1723000–1724000
# Inserted rows 1724000–1725000
# Inserted rows 1725000–1726000
# Inserted rows 1726000–1727000
# Inserted rows 1727000–1728000
# Inserted rows 1728000–1729000
# Inserted rows 1729000–1730000
# Inserted rows 1730000–1731000
# Inserted rows 1731000–1732000
# Inserted rows 1732000–1733000
# Inserted rows 1733000–1734000
# Inserted rows 1734000–1735000
# Inserted rows 1735000–1736000
# Inserted rows 1736000–1737000
# Inserted rows 1737000–1738000
# Inserted rows 1738000–1739000
# Inserted rows 1739000–1740000
# Inserted rows 1740000–1741000
# Inserted rows 1741000–1742000
# Inserted rows 1742000–1743000
# Inserted rows 1743000–1744000
# Inserted rows 1744000–1745000
# Inserted rows 1745000–1746000
# Inserted rows 1746000–1747000
# Inserted rows 1747000–1748000
# Inserted rows 1748000–1749000
# Inserted rows 1749000–1750000
# Inserted rows 1750000–1751000
# Inserted rows 1751000–1752000
# Inserted rows 1752000–1753000
# Inserted rows 1753000–1754000
# Inserted rows 1754000–1755000
# Inserted rows 1755000–1756000
# Inserted rows 1756000–1757000
# Inserted rows 1757000–1758000
# Inserted rows 1758000–1759000
# Inserted rows 1759000–1760000
# Inserted rows 1760000–1761000
# Inserted rows 1761000–1762000
# Inserted rows 1762000–1763000
# Inserted rows 1763000–1764000
# Inserted rows 1764000–1765000
# Inserted rows 1765000–1766000
# Inserted rows 1766000–1767000
# Inserted rows 1767000–1768000
# Inserted rows 1768000–1769000
# Inserted rows 1769000–1770000
# Inserted rows 1770000–1771000
# Inserted rows 1771000–1772000
# Inserted rows 1772000–1773000
# Inserted rows 1773000–1774000
# Inserted rows 1774000–1775000
# Inserted rows 1775000–1776000
# Inserted rows 1776000–1777000
# Inserted rows 1777000–1778000
# Inserted rows 1778000–1779000
# Inserted rows 1779000–1780000
# Inserted rows 1780000–1781000
# Inserted rows 1781000–1782000
# Inserted rows 1782000–1783000
# Inserted rows 1783000–1784000
# Inserted rows 1784000–1785000
# Inserted rows 1785000–1786000
# Inserted rows 1786000–1787000
# Inserted rows 1787000–1788000
# Inserted rows 1788000–1789000
# Inserted rows 1789000–1790000
# Inserted rows 1790000–1791000
# Inserted rows 1791000–1792000
# Inserted rows 1792000–1793000
# Inserted rows 1793000–1794000
# Inserted rows 1794000–1795000
# Inserted rows 1795000–1796000
# Inserted rows 1796000–1797000
# Inserted rows 1797000–1798000
# Inserted rows 1798000–1799000
# Inserted rows 1799000–1800000
# Inserted rows 1800000–1801000
# Inserted rows 1801000–1802000
# Inserted rows 1802000–1803000
# Inserted rows 1803000–1804000
# Inserted rows 1804000–1805000
# Inserted rows 1805000–1806000
# Inserted rows 1806000–1807000
# Inserted rows 1807000–1808000
# Inserted rows 1808000–1809000
# Inserted rows 1809000–1810000
# Inserted rows 1810000–1811000
# Inserted rows 1811000–1812000
# Inserted rows 1812000–1813000
# Inserted rows 1813000–1814000
# Inserted rows 1814000–1815000
# Inserted rows 1815000–1816000
# Inserted rows 1816000–1817000
# Inserted rows 1817000–1818000
# Inserted rows 1818000–1819000
# Inserted rows 1819000–1820000
# Inserted rows 1820000–1821000
# Inserted rows 1821000–1822000
# Inserted rows 1822000–1823000
# Inserted rows 1823000–1824000
# Inserted rows 1824000–1825000
# Inserted rows 1825000–1826000
# Inserted rows 1826000–1827000
# Inserted rows 1827000–1828000
# Inserted rows 1828000–1829000
# Inserted rows 1829000–1830000
# Inserted rows 1830000–1831000
# Inserted rows 1831000–1832000
# Inserted rows 1832000–1833000
# Inserted rows 1833000–1834000
# Inserted rows 1834000–1835000
# Inserted rows 1835000–1836000
# Inserted rows 1836000–1837000
# Inserted rows 1837000–1838000
# Inserted rows 1838000–1839000
# Inserted rows 1839000–1840000
# Inserted rows 1840000–1841000
# Inserted rows 1841000–1842000
# Inserted rows 1842000–1843000
# Inserted rows 1843000–1844000
# Inserted rows 1844000–1845000
# Inserted rows 1845000–1846000
# Inserted rows 1846000–1847000
# Inserted rows 1847000–1848000
# Inserted rows 1848000–1849000
# Inserted rows 1849000–1850000
# Inserted rows 1850000–1851000
# Inserted rows 1851000–1852000
# Inserted rows 1852000–1853000
# Inserted rows 1853000–1854000
# Inserted rows 1854000–1855000
# Inserted rows 1855000–1856000
# Inserted rows 1856000–1857000
# Inserted rows 1857000–1858000
# Inserted rows 1858000–1859000
# Inserted rows 1859000–1860000
# Inserted rows 1860000–1861000
# Inserted rows 1861000–1862000
# Inserted rows 1862000–1863000
# Inserted rows 1863000–1864000
# Inserted rows 1864000–1865000
# Inserted rows 1865000–1866000
# Inserted rows 1866000–1867000
# Inserted rows 1867000–1868000
# Inserted rows 1868000–1869000
# Inserted rows 1869000–1870000
# Inserted rows 1870000–1871000
# Inserted rows 1871000–1872000
# Inserted rows 1872000–1873000
# Inserted rows 1873000–1874000
# Inserted rows 1874000–1875000
# Inserted rows 1875000–1876000
# Inserted rows 1876000–1877000
# Inserted rows 1877000–1878000
# Inserted rows 1878000–1879000
# Inserted rows 1879000–1880000
# Inserted rows 1880000–1881000
# Inserted rows 1881000–1882000
# Inserted rows 1882000–1883000
# Inserted rows 1883000–1884000
# Inserted rows 1884000–1885000
# Inserted rows 1885000–1886000
# Inserted rows 1886000–1887000
# Inserted rows 1887000–1888000
# Inserted rows 1888000–1889000
# Inserted rows 1889000–1890000
# Inserted rows 1890000–1891000
# Inserted rows 1891000–1892000
# Inserted rows 1892000–1893000
# Inserted rows 1893000–1894000
# Inserted rows 1894000–1895000
# Inserted rows 1895000–1896000
# Inserted rows 1896000–1897000
# Inserted rows 1897000–1898000
# Inserted rows 1898000–1899000
# Inserted rows 1899000–1900000
# Inserted rows 1900000–1901000
# Inserted rows 1901000–1902000
# Inserted rows 1902000–1903000
# Inserted rows 1903000–1904000
# Inserted rows 1904000–1905000
# Inserted rows 1905000–1906000
# Inserted rows 1906000–1907000
# Inserted rows 1907000–1908000
# Inserted rows 1908000–1909000
# Inserted rows 1909000–1910000
# Inserted rows 1910000–1911000
# Inserted rows 1911000–1912000
# Inserted rows 1912000–1913000
# Inserted rows 1913000–1914000
# Inserted rows 1914000–1915000
# Inserted rows 1915000–1916000
# Inserted rows 1916000–1917000
# Inserted rows 1917000–1918000
# Inserted rows 1918000–1919000
# Inserted rows 1919000–1920000
# Inserted rows 1920000–1921000
# Inserted rows 1921000–1922000
# Inserted rows 1922000–1923000
# Inserted rows 1923000–1924000
# Inserted rows 1924000–1925000
# Inserted rows 1925000–1926000
# Inserted rows 1926000–1927000
# Inserted rows 1927000–1928000
# Inserted rows 1928000–1929000
# Inserted rows 1929000–1930000
# Inserted rows 1930000–1931000
# Inserted rows 1931000–1932000
# Inserted rows 1932000–1933000
# Inserted rows 1933000–1934000
# Inserted rows 1934000–1935000
# Inserted rows 1935000–1936000
# Inserted rows 1936000–1937000
# Inserted rows 1937000–1938000
# Inserted rows 1938000–1939000
# Inserted rows 1939000–1940000
# Inserted rows 1940000–1941000
# Inserted rows 1941000–1942000
# Inserted rows 1942000–1943000
# Inserted rows 1943000–1944000
# Inserted rows 1944000–1945000
# Inserted rows 1945000–1946000
# Inserted rows 1946000–1947000
# Inserted rows 1947000–1948000
# Inserted rows 1948000–1949000
# Inserted rows 1949000–1950000
# Inserted rows 1950000–1951000
# Inserted rows 1951000–1952000
# Inserted rows 1952000–1953000
# Inserted rows 1953000–1954000
# Inserted rows 1954000–1955000
# Inserted rows 1955000–1956000
# Inserted rows 1956000–1957000
# Inserted rows 1957000–1958000
# Inserted rows 1958000–1959000
# Inserted rows 1959000–1960000
# Inserted rows 1960000–1961000
# Inserted rows 1961000–1962000
# Inserted rows 1962000–1963000
# Inserted rows 1963000–1964000
# Inserted rows 1964000–1965000
# Inserted rows 1965000–1966000
# Inserted rows 1966000–1967000
# Inserted rows 1967000–1968000
# Inserted rows 1968000–1969000
# Inserted rows 1969000–1970000
# Inserted rows 1970000–1971000
# Inserted rows 1971000–1972000
# Inserted rows 1972000–1973000
# Inserted rows 1973000–1974000
# Inserted rows 1974000–1975000
# Inserted rows 1975000–1976000
# Inserted rows 1976000–1977000
# Inserted rows 1977000–1978000
# Inserted rows 1978000–1979000
# Inserted rows 1979000–1980000
# Inserted rows 1980000–1981000
# Inserted rows 1981000–1982000
# Inserted rows 1982000–1983000
# Inserted rows 1983000–1984000
# Inserted rows 1984000–1985000
# Inserted rows 1985000–1986000
# Inserted rows 1986000–1987000
# Inserted rows 1987000–1988000
# Inserted rows 1988000–1989000
# Inserted rows 1989000–1990000
# Inserted rows 1990000–1991000
# Inserted rows 1991000–1992000
# Inserted rows 1992000–1993000
# Inserted rows 1993000–1994000
# Inserted rows 1994000–1995000
# Inserted rows 1995000–1996000
# Inserted rows 1996000–1997000
# Inserted rows 1997000–1998000
# Inserted rows 1998000–1999000
# Inserted rows 1999000–2000000
# Finished inserting 2000000 rows into 'imdb_unindexed' in 66.44 seconds
